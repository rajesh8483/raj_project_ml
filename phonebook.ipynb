# %%
phone_book = {}

def add_contact(name, number):
    phone_book[name] = number
    print(f"Added {name} with number {number}")

def delete_contact(name):
    if name in phone_book:
        del phone_book[name]
        print(f"Deleted contact {name}")
    else:
        print(f"Contact {name} not found")

def update_contact(name, number):
    if name in phone_book:
        phone_book[name] = number
        print(f"Updated {name}'s number to {number}")
    else:
        print(f"Contact {name} not found")

def view_contact(name):
    if name in phone_book:
        print(f"{name}'s number is {phone_book[name]}")
    else:
        print(f"Contact {name} not found")

def list_contacts():
    if phone_book:
        for name, number in phone_book.items():
            print(f"{name}: {number}")
    else:
        print("Phone book is empty")

def menu():
    while True:
        print("\nPhone Book Menu")
        print("1. Add Contact")
        print("2. Delete Contact")
        print("3. Update Contact")
        print("4. View Contact")
        print("5. List All Contacts")
        print("6. Exit")
        choice = input("Choose an option: ")

        if choice == '1':
            name = input("Enter name: ")
            number = input("Enter phone number: ")
            add_contact(name, number)
        elif choice == '2':
            name = input("Enter name to delete: ")
            delete_contact(name)
        elif choice == '3':
            name = input("Enter name to update: ")
            number = input("Enter new phone number: ")
            update_contact(name, number)
        elif choice == '4':
            name = input("Enter name to view: ")
            view_contact(name)
        elif choice == '5':
            list_contacts()
        elif choice == '6':
            print("Exiting phone book.")
            break
        else:
            print("Invalid choice, please try again.")


menu()
# Out:
# Phone Book Menu
# 1. Add Contact
# 2. Delete Contact
# 3. Update Contact
# 4. View Contact
# 5. List All Contacts
# 6. Exit
# Choose an option: 1
# Enter name: rajesh
# Enter phone number: 8483964395
# Added rajesh with number 8483964395
#
# Phone Book Menu
# 1. Add Contact
# 2. Delete Contact
# 3. Update Contact
# 4. View Contact
# 5. List All Contacts
# 6. Exit
# Choose an option: 3
# Enter name to update: rpatil
# Enter new phone number: 8483964395
# Contact rpatil not found
#
# Phone Book Menu
# 1. Add Contact
# 2. Delete Contact
# 3. Update Contact
# 4. View Contact
# 5. List All Contacts
# 6. Exit
# Choose an option:
# Invalid choice, please try again.
#
# Phone Book Menu
# 1. Add Contact
# 2. Delete Contact
# 3. Update Contact
# 4. View Contact
# 5. List All Contacts
# 6. Exit
